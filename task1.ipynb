# %% [markdown]
# # The Spark Foundation

# %% [markdown]
# # Predict the percentage of an student based on the no. of study hours.

# %% [markdown]
# **Step 1:- Importing Python Library**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# **Step 2:- Importing data-set**

# %%
data = pd.read_csv("data.csv")
print("Importing Data Successfully")
# Out:
# Importing Data Successfully

# %% [markdown]
# **Step 3:- Check weather data imported successfully or not?**

# %%
print("For this we print first 10 data of Data-set ")
data.head(10)
# Out:
# For this we print first 10 data of Data-set
#    Hours  Scores
# 0    2.5      21
# 1    5.1      47
# 2    3.2      27
# 3    8.5      75
# 4    3.5      30
# 5    1.5      20
# 6    9.2      88
# 7    5.5      60
# 8    8.3      81
# 9    2.7      25

# %%
print("You have correctly imported Data-set")
# Out:
# You have correctly imported Data-set

# %% [markdown]
# **Step 4:- Plot the Graph, for detail Analysis of Data-set**

# %%
data.plot(x='Hours',y='Scores',style='1')
plt.title('Hours vs Percentage')
plt.xlabel('Hours Studied')
plt.ylabel('Percentage Score')
plt.show()

# %%
data.plot.pie(x='Hours' ,y='Scores')
# Out:
# <AxesSubplot:ylabel='Scores'>

# %%
data.plot.scatter(x='Hours' ,y='Scores')
# Out:
# <AxesSubplot:xlabel='Hours', ylabel='Scores'>

# %%
data.plot.bar(x='Hours' ,y='Scores')
# Out:
# <AxesSubplot:xlabel='Hours'>

# %%
data.sort_values(["Hours"], axis=0, ascending=[True],inplace=True)
data.head(10)
data.plot.bar(x='Hours', y='Scores')
# Out:
# <AxesSubplot:xlabel='Hours'>

# %% [markdown]
# # After plotting different graph, we have observed that as Study Hours increases, score is also increases. Which is a good sign of correct data. In our daily life, we have observed the same phenomenon.

# %% [markdown]
# **Step 5:- Now, we have prepared the data of our model**

# %%
x = data.iloc[:, :-1].values
y = data.iloc[:, 1].values
# print(x)

# %% [markdown]
# **Step 6:- Now, we have divide the data for training and testing the model**

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=0)

# %% [markdown]
# # Training the Algorithm

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()

# from sklearn.ensemble import RandomForestRegressor
# regressor = RandomForestRegressor(n_estimators = 1000, random_state = 42)

regressor.fit(x_train, y_train)
print("Training complete.")
# Out:
# Training complete.

# %% [markdown]
# **Step 7:-Now, our Model is ready. Its time to test it.**

# %%
print(x_test)
print("Prediction of Score")
y_pred = regressor.predict(x_test)
print(y_pred)
# Out:
# [[2.7]
#  [1.9]
#  [7.7]
#  [6.1]
#  [4.5]]
# Prediction of Score
# [28.6177145  20.88803334 76.92822173 61.46885942 46.0094971 ]

# %% [markdown]
# **Step 8:- Now, Checking the accuracy of our model**

# %%
df = pd.DataFrame({'Actual': y_test, 'Predicted': y_pred})

df
# Out:
#    Actual  Predicted
# 0      30  28.617714
# 1      24  20.888033
# 2      85  76.928222
# 3      67  61.468859
# 4      41  46.009497

# %% [markdown]
# **Step 9:- Now, its time to prediction with custom input**

# %%
Hours = [[9.25]]
pred = regressor.predict(Hours)
print(pred)
# Out:
# [91.90447898]

# %% [markdown]
# # Evaluating the model

# %%
from sklearn import metrics
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred))
# Out:
# Mean Absolute Error: 4.621333622532769
